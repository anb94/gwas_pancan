# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_columns', 120)

# %% [markdown]
# Import info files:

# %% [markdown]
# - Hispanic American:

# %%
SHAREchr1ha_info = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/SHAREchr1ha.info", sep="\t", comment='#')
SHAREchr2ha_info = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/SHAREchr2ha.info", sep="\t", comment='#')
SHAREchr3ha_info = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/SHAREchr3ha.info", sep="\t", comment='#')
SHAREchr4ha_info = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/SHAREchr4ha.info", sep="\t", comment='#')
SHAREchr5ha_info = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/SHAREchr5ha.info", sep="\t", comment='#')
SHAREchr6ha_info = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/SHAREchr6ha.info", sep="\t", comment='#')
SHAREchr7ha_info = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/SHAREchr7ha.info", sep="\t", comment='#')
SHAREchr8ha_info = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/SHAREchr8ha.info", sep="\t", comment='#')
SHAREchr9ha_info = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/SHAREchr9ha.info", sep="\t", comment='#')
SHAREchr10ha_info = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/SHAREchr10ha.info", sep="\t", comment='#')
SHAREchr11ha_info = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/SHAREchr11ha.info", sep="\t", comment='#')
SHAREchr12ha_info = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/SHAREchr12ha.info", sep="\t", comment='#')
SHAREchr13ha_info = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/SHAREchr13ha.info", sep="\t", comment='#')
SHAREchr14ha_info = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/SHAREchr14ha.info", sep="\t", comment='#')
SHAREchr15ha_info = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/SHAREchr15ha.info", sep="\t", comment='#')
SHAREchr16ha_info = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/SHAREchr16ha.info", sep="\t", comment='#')
SHAREchr17ha_info = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/SHAREchr17ha.info", sep="\t", comment='#')
SHAREchr18ha_info = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/SHAREchr18ha.info", sep="\t", comment='#')
SHAREchr19ha_info = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/SHAREchr19ha.info", sep="\t", comment='#')
SHAREchr20ha_info = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/SHAREchr20ha.info", sep="\t", comment='#')
SHAREchr21ha_info = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/SHAREchr21ha.info", sep="\t", comment='#')
SHAREchr22ha_info = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/SHAREchr22ha.info", sep="\t", comment='#')

# %% [markdown]
# - African American

# %%
SHAREchr1aa_info = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/SHAREchr1aa.info", sep="\t", comment='#')
SHAREchr2aa_info = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/SHAREchr2aa.info", sep="\t", comment='#')
SHAREchr3aa_info = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/SHAREchr3aa.info", sep="\t", comment='#')
SHAREchr4aa_info = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/SHAREchr4aa.info", sep="\t", comment='#')
SHAREchr5aa_info = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/SHAREchr5aa.info", sep="\t", comment='#')
SHAREchr6aa_info = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/SHAREchr6aa.info", sep="\t", comment='#')
SHAREchr7aa_info = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/SHAREchr7aa.info", sep="\t", comment='#')
SHAREchr8aa_info = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/SHAREchr8aa.info", sep="\t", comment='#')
SHAREchr9aa_info = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/SHAREchr9aa.info", sep="\t", comment='#')
SHAREchr10aa_info = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/SHAREchr10aa.info", sep="\t", comment='#')
SHAREchr11aa_info = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/SHAREchr11aa.info", sep="\t", comment='#')
SHAREchr12aa_info = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/SHAREchr12aa.info", sep="\t", comment='#')
SHAREchr13aa_info = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/SHAREchr13aa.info", sep="\t", comment='#')
SHAREchr14aa_info = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/SHAREchr14aa.info", sep="\t", comment='#')
SHAREchr15aa_info = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/SHAREchr15aa.info", sep="\t", comment='#')
SHAREchr16aa_info = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/SHAREchr16aa.info", sep="\t", comment='#')
SHAREchr17aa_info = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/SHAREchr17aa.info", sep="\t", comment='#')
SHAREchr18aa_info = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/SHAREchr18aa.info", sep="\t", comment='#')
SHAREchr19aa_info = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/SHAREchr19aa.info", sep="\t", comment='#')
SHAREchr20aa_info = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/SHAREchr20aa.info", sep="\t", comment='#')
SHAREchr21aa_info = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/SHAREchr21aa.info", sep="\t", comment='#')
SHAREchr22aa_info = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/SHAREchr22aa.info", sep="\t", comment='#')

# %% [markdown]
# Import position files:

# %% [markdown]
# - Hispanic American:

# %%
SHAREchr1ha_info_pos = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/info_positions/SHAREchr1ha.txt", sep="\t", comment='#')
SHAREchr2ha_info_pos = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/info_positions/SHAREchr2ha.txt", sep="\t", comment='#')
SHAREchr3ha_info_pos = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/info_positions/SHAREchr3ha.txt", sep="\t", comment='#')
SHAREchr4ha_info_pos = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/info_positions/SHAREchr4ha.txt", sep="\t", comment='#')
SHAREchr5ha_info_pos = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/info_positions/SHAREchr5ha.txt", sep="\t", comment='#')
SHAREchr6ha_info_pos = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/info_positions/SHAREchr6ha.txt", sep="\t", comment='#')
SHAREchr7ha_info_pos = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/info_positions/SHAREchr7ha.txt", sep="\t", comment='#')
SHAREchr8ha_info_pos = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/info_positions/SHAREchr8ha.txt", sep="\t", comment='#')
SHAREchr9ha_info_pos = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/info_positions/SHAREchr9ha.txt", sep="\t", comment='#')
SHAREchr10ha_info_pos = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/info_positions/SHAREchr10ha.txt", sep="\t", comment='#')
SHAREchr11ha_info_pos = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/info_positions/SHAREchr11ha.txt", sep="\t", comment='#')
SHAREchr12ha_info_pos = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/info_positions/SHAREchr12ha.txt", sep="\t", comment='#')
SHAREchr13ha_info_pos = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/info_positions/SHAREchr13ha.txt", sep="\t", comment='#')
SHAREchr14ha_info_pos = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/info_positions/SHAREchr14ha.txt", sep="\t", comment='#')
SHAREchr15ha_info_pos = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/info_positions/SHAREchr15ha.txt", sep="\t", comment='#')
SHAREchr16ha_info_pos = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/info_positions/SHAREchr16ha.txt", sep="\t", comment='#')
SHAREchr17ha_info_pos = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/info_positions/SHAREchr17ha.txt", sep="\t", comment='#')
SHAREchr18ha_info_pos = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/info_positions/SHAREchr18ha.txt", sep="\t", comment='#')
SHAREchr19ha_info_pos = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/info_positions/SHAREchr19ha.txt", sep="\t", comment='#')
SHAREchr20ha_info_pos = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/info_positions/SHAREchr20ha.txt", sep="\t", comment='#')
SHAREchr21ha_info_pos = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/info_positions/SHAREchr21ha.txt", sep="\t", comment='#')
SHAREchr22ha_info_pos = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/info_positions/SHAREchr22ha.txt", sep="\t", comment='#')

# %% [markdown]
# - African American:

# %%
SHAREchr1aa_info_pos = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/info_positions/SHAREchr1aa.txt", sep="\t", comment='#')
SHAREchr2aa_info_pos = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/info_positions/SHAREchr2aa.txt", sep="\t", comment='#')
SHAREchr3aa_info_pos = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/info_positions/SHAREchr3aa.txt", sep="\t", comment='#')
SHAREchr4aa_info_pos = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/info_positions/SHAREchr4aa.txt", sep="\t", comment='#')
SHAREchr5aa_info_pos = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/info_positions/SHAREchr5aa.txt", sep="\t", comment='#')
SHAREchr6aa_info_pos = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/info_positions/SHAREchr6aa.txt", sep="\t", comment='#')
SHAREchr7aa_info_pos = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/info_positions/SHAREchr7aa.txt", sep="\t", comment='#')
SHAREchr8aa_info_pos = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/info_positions/SHAREchr8aa.txt", sep="\t", comment='#')
SHAREchr9aa_info_pos = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/info_positions/SHAREchr9aa.txt", sep="\t", comment='#')
SHAREchr10aa_info_pos = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/info_positions/SHAREchr10aa.txt", sep="\t", comment='#')
SHAREchr11aa_info_pos = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/info_positions/SHAREchr11aa.txt", sep="\t", comment='#')
SHAREchr12aa_info_pos = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/info_positions/SHAREchr12aa.txt", sep="\t", comment='#')
SHAREchr13aa_info_pos = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/info_positions/SHAREchr13aa.txt", sep="\t", comment='#')
SHAREchr14aa_info_pos = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/info_positions/SHAREchr14aa.txt", sep="\t", comment='#')
SHAREchr15aa_info_pos = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/info_positions/SHAREchr15aa.txt", sep="\t", comment='#')
SHAREchr16aa_info_pos = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/info_positions/SHAREchr16aa.txt", sep="\t", comment='#')
SHAREchr17aa_info_pos = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/info_positions/SHAREchr17aa.txt", sep="\t", comment='#')
SHAREchr18aa_info_pos = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/info_positions/SHAREchr18aa.txt", sep="\t", comment='#')
SHAREchr19aa_info_pos = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/info_positions/SHAREchr19aa.txt", sep="\t", comment='#')
SHAREchr20aa_info_pos = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/info_positions/SHAREchr20aa.txt", sep="\t", comment='#')
SHAREchr21aa_info_pos = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/info_positions/SHAREchr21aa.txt", sep="\t", comment='#')
SHAREchr22aa_info_pos = pd.read_csv("/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/info_positions/SHAREchr22aa.txt", sep="\t", comment='#')

# %% [markdown]
# Join and rename SNP column in info_pos dfs to position

# %% [markdown]
# - Hispanic American

# %%
SHAREchr1ha_posfile = pd.concat([SHAREchr1ha_info[['SNP']], SHAREchr1ha_info_pos], ignore_index=True, sort=False, axis=1)
SHAREchr1ha_posfile = SHAREchr1ha_posfile.rename(columns={0: "SNP", 1: "position"})

SHAREchr2ha_posfile = pd.concat([SHAREchr2ha_info[['SNP']], SHAREchr2ha_info_pos], ignore_index=True, sort=False, axis=1)
SHAREchr2ha_posfile = SHAREchr2ha_posfile.rename(columns={0: "SNP", 1: "position"})

SHAREchr3ha_posfile = pd.concat([SHAREchr3ha_info[['SNP']], SHAREchr3ha_info_pos], ignore_index=True, sort=False, axis=1)
SHAREchr3ha_posfile = SHAREchr3ha_posfile.rename(columns={0: "SNP", 1: "position"})

SHAREchr4ha_posfile = pd.concat([SHAREchr4ha_info[['SNP']], SHAREchr4ha_info_pos], ignore_index=True, sort=False, axis=1)
SHAREchr4ha_posfile = SHAREchr4ha_posfile.rename(columns={0: "SNP", 1: "position"})

SHAREchr5ha_posfile = pd.concat([SHAREchr5ha_info[['SNP']], SHAREchr5ha_info_pos], ignore_index=True, sort=False, axis=1)
SHAREchr5ha_posfile = SHAREchr5ha_posfile.rename(columns={0: "SNP", 1: "position"})

SHAREchr6ha_posfile = pd.concat([SHAREchr6ha_info[['SNP']], SHAREchr6ha_info_pos], ignore_index=True, sort=False, axis=1)
SHAREchr6ha_posfile = SHAREchr6ha_posfile.rename(columns={0: "SNP", 1: "position"})

SHAREchr7ha_posfile = pd.concat([SHAREchr7ha_info[['SNP']], SHAREchr7ha_info_pos], ignore_index=True, sort=False, axis=1)
SHAREchr7ha_posfile = SHAREchr7ha_posfile.rename(columns={0: "SNP", 1: "position"})

SHAREchr8ha_posfile = pd.concat([SHAREchr8ha_info[['SNP']], SHAREchr8ha_info_pos], ignore_index=True, sort=False, axis=1)
SHAREchr8ha_posfile = SHAREchr8ha_posfile.rename(columns={0: "SNP", 1: "position"})

SHAREchr9ha_posfile = pd.concat([SHAREchr9ha_info[['SNP']], SHAREchr9ha_info_pos], ignore_index=True, sort=False, axis=1)
SHAREchr9ha_posfile = SHAREchr9ha_posfile.rename(columns={0: "SNP", 1: "position"})

SHAREchr10ha_posfile = pd.concat([SHAREchr10ha_info[['SNP']], SHAREchr10ha_info_pos], ignore_index=True, sort=False, axis=1)
SHAREchr10ha_posfile = SHAREchr10ha_posfile.rename(columns={0: "SNP", 1: "position"})

SHAREchr11ha_posfile = pd.concat([SHAREchr11ha_info[['SNP']], SHAREchr11ha_info_pos], ignore_index=True, sort=False, axis=1)
SHAREchr11ha_posfile = SHAREchr11ha_posfile.rename(columns={0: "SNP", 1: "position"})

SHAREchr12ha_posfile = pd.concat([SHAREchr12ha_info[['SNP']], SHAREchr12ha_info_pos], ignore_index=True, sort=False, axis=1)
SHAREchr12ha_posfile = SHAREchr12ha_posfile.rename(columns={0: "SNP", 1: "position"})

SHAREchr13ha_posfile = pd.concat([SHAREchr13ha_info[['SNP']], SHAREchr13ha_info_pos], ignore_index=True, sort=False, axis=1)
SHAREchr13ha_posfile = SHAREchr13ha_posfile.rename(columns={0: "SNP", 1: "position"})

SHAREchr14ha_posfile = pd.concat([SHAREchr14ha_info[['SNP']], SHAREchr14ha_info_pos], ignore_index=True, sort=False, axis=1)
SHAREchr14ha_posfile = SHAREchr14ha_posfile.rename(columns={0: "SNP", 1: "position"})

SHAREchr15ha_posfile = pd.concat([SHAREchr15ha_info[['SNP']], SHAREchr15ha_info_pos], ignore_index=True, sort=False, axis=1)
SHAREchr15ha_posfile = SHAREchr15ha_posfile.rename(columns={0: "SNP", 1: "position"})

SHAREchr16ha_posfile = pd.concat([SHAREchr16ha_info[['SNP']], SHAREchr16ha_info_pos], ignore_index=True, sort=False, axis=1)
SHAREchr16ha_posfile = SHAREchr16ha_posfile.rename(columns={0: "SNP", 1: "position"})

SHAREchr17ha_posfile = pd.concat([SHAREchr17ha_info[['SNP']], SHAREchr17ha_info_pos], ignore_index=True, sort=False, axis=1)
SHAREchr17ha_posfile = SHAREchr17ha_posfile.rename(columns={0: "SNP", 1: "position"})

SHAREchr18ha_posfile = pd.concat([SHAREchr18ha_info[['SNP']], SHAREchr18ha_info_pos], ignore_index=True, sort=False, axis=1)
SHAREchr18ha_posfile = SHAREchr18ha_posfile.rename(columns={0: "SNP", 1: "position"})

SHAREchr19ha_posfile = pd.concat([SHAREchr19ha_info[['SNP']], SHAREchr19ha_info_pos], ignore_index=True, sort=False, axis=1)
SHAREchr19ha_posfile = SHAREchr19ha_posfile.rename(columns={0: "SNP", 1: "position"})

SHAREchr20ha_posfile = pd.concat([SHAREchr20ha_info[['SNP']], SHAREchr20ha_info_pos], ignore_index=True, sort=False, axis=1)
SHAREchr20ha_posfile = SHAREchr20ha_posfile.rename(columns={0: "SNP", 1: "position"})

SHAREchr21ha_posfile = pd.concat([SHAREchr21ha_info[['SNP']], SHAREchr21ha_info_pos], ignore_index=True, sort=False, axis=1)
SHAREchr21ha_posfile = SHAREchr21ha_posfile.rename(columns={0: "SNP", 1: "position"})

SHAREchr22ha_posfile = pd.concat([SHAREchr22ha_info[['SNP']], SHAREchr22ha_info_pos], ignore_index=True, sort=False, axis=1)
SHAREchr22ha_posfile = SHAREchr22ha_posfile.rename(columns={0: "SNP", 1: "position"})

# %% [markdown]
# - African American

# %%
SHAREchr1aa_posfile = pd.concat([SHAREchr1aa_info[['SNP']], SHAREchr1aa_info_pos], ignore_index=True, sort=False, axis=1)
SHAREchr1aa_posfile = SHAREchr1aa_posfile.rename(columns={0: "SNP", 1: "position"})

SHAREchr2aa_posfile = pd.concat([SHAREchr2aa_info[['SNP']], SHAREchr2aa_info_pos], ignore_index=True, sort=False, axis=1)
SHAREchr2aa_posfile = SHAREchr2aa_posfile.rename(columns={0: "SNP", 1: "position"})

SHAREchr3aa_posfile = pd.concat([SHAREchr3aa_info[['SNP']], SHAREchr3aa_info_pos], ignore_index=True, sort=False, axis=1)
SHAREchr3aa_posfile = SHAREchr3aa_posfile.rename(columns={0: "SNP", 1: "position"})

SHAREchr4aa_posfile = pd.concat([SHAREchr4aa_info[['SNP']], SHAREchr4aa_info_pos], ignore_index=True, sort=False, axis=1)
SHAREchr4aa_posfile = SHAREchr4aa_posfile.rename(columns={0: "SNP", 1: "position"})

SHAREchr5aa_posfile = pd.concat([SHAREchr5aa_info[['SNP']], SHAREchr5aa_info_pos], ignore_index=True, sort=False, axis=1)
SHAREchr5aa_posfile = SHAREchr5aa_posfile.rename(columns={0: "SNP", 1: "position"})

SHAREchr6aa_posfile = pd.concat([SHAREchr6aa_info[['SNP']], SHAREchr6aa_info_pos], ignore_index=True, sort=False, axis=1)
SHAREchr6aa_posfile = SHAREchr6aa_posfile.rename(columns={0: "SNP", 1: "position"})

SHAREchr7aa_posfile = pd.concat([SHAREchr7aa_info[['SNP']], SHAREchr7aa_info_pos], ignore_index=True, sort=False, axis=1)
SHAREchr7aa_posfile = SHAREchr7aa_posfile.rename(columns={0: "SNP", 1: "position"})

SHAREchr8aa_posfile = pd.concat([SHAREchr8aa_info[['SNP']], SHAREchr8aa_info_pos], ignore_index=True, sort=False, axis=1)
SHAREchr8aa_posfile = SHAREchr8aa_posfile.rename(columns={0: "SNP", 1: "position"})

SHAREchr9aa_posfile = pd.concat([SHAREchr9aa_info[['SNP']], SHAREchr9aa_info_pos], ignore_index=True, sort=False, axis=1)
SHAREchr9aa_posfile = SHAREchr9aa_posfile.rename(columns={0: "SNP", 1: "position"})

SHAREchr10aa_posfile = pd.concat([SHAREchr10aa_info[['SNP']], SHAREchr10aa_info_pos], ignore_index=True, sort=False, axis=1)
SHAREchr10aa_posfile = SHAREchr10aa_posfile.rename(columns={0: "SNP", 1: "position"})

SHAREchr11aa_posfile = pd.concat([SHAREchr11aa_info[['SNP']], SHAREchr11aa_info_pos], ignore_index=True, sort=False, axis=1)
SHAREchr11aa_posfile = SHAREchr11aa_posfile.rename(columns={0: "SNP", 1: "position"})

SHAREchr12aa_posfile = pd.concat([SHAREchr12aa_info[['SNP']], SHAREchr12aa_info_pos], ignore_index=True, sort=False, axis=1)
SHAREchr12aa_posfile = SHAREchr12aa_posfile.rename(columns={0: "SNP", 1: "position"})

SHAREchr13aa_posfile = pd.concat([SHAREchr13aa_info[['SNP']], SHAREchr13aa_info_pos], ignore_index=True, sort=False, axis=1)
SHAREchr13aa_posfile = SHAREchr13aa_posfile.rename(columns={0: "SNP", 1: "position"})

SHAREchr14aa_posfile = pd.concat([SHAREchr14aa_info[['SNP']], SHAREchr14aa_info_pos], ignore_index=True, sort=False, axis=1)
SHAREchr14aa_posfile = SHAREchr14aa_posfile.rename(columns={0: "SNP", 1: "position"})

SHAREchr15aa_posfile = pd.concat([SHAREchr15aa_info[['SNP']], SHAREchr15aa_info_pos], ignore_index=True, sort=False, axis=1)
SHAREchr15aa_posfile = SHAREchr15aa_posfile.rename(columns={0: "SNP", 1: "position"})

SHAREchr16aa_posfile = pd.concat([SHAREchr16aa_info[['SNP']], SHAREchr16aa_info_pos], ignore_index=True, sort=False, axis=1)
SHAREchr16aa_posfile = SHAREchr16aa_posfile.rename(columns={0: "SNP", 1: "position"})

SHAREchr17aa_posfile = pd.concat([SHAREchr17aa_info[['SNP']], SHAREchr17aa_info_pos], ignore_index=True, sort=False, axis=1)
SHAREchr17aa_posfile = SHAREchr17aa_posfile.rename(columns={0: "SNP", 1: "position"})

SHAREchr18aa_posfile = pd.concat([SHAREchr18aa_info[['SNP']], SHAREchr18aa_info_pos], ignore_index=True, sort=False, axis=1)
SHAREchr18aa_posfile = SHAREchr18aa_posfile.rename(columns={0: "SNP", 1: "position"})

SHAREchr19aa_posfile = pd.concat([SHAREchr19aa_info[['SNP']], SHAREchr19aa_info_pos], ignore_index=True, sort=False, axis=1)
SHAREchr19aa_posfile = SHAREchr19aa_posfile.rename(columns={0: "SNP", 1: "position"})

SHAREchr20aa_posfile = pd.concat([SHAREchr20aa_info[['SNP']], SHAREchr20aa_info_pos], ignore_index=True, sort=False, axis=1)
SHAREchr20aa_posfile = SHAREchr20aa_posfile.rename(columns={0: "SNP", 1: "position"})

SHAREchr21aa_posfile = pd.concat([SHAREchr21aa_info[['SNP']], SHAREchr21aa_info_pos], ignore_index=True, sort=False, axis=1)
SHAREchr21aa_posfile = SHAREchr21aa_posfile.rename(columns={0: "SNP", 1: "position"})

SHAREchr22aa_posfile = pd.concat([SHAREchr22aa_info[['SNP']], SHAREchr22aa_info_pos], ignore_index=True, sort=False, axis=1)
SHAREchr22aa_posfile = SHAREchr22aa_posfile.rename(columns={0: "SNP", 1: "position"})

# %% [markdown]
# Save posfiles:

# %%
SHAREchr1ha_posfile.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/ha/SHAREchr1ha_posfile.csv', sep='\t', index=False)
SHAREchr2ha_posfile.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/ha/SHAREchr2ha_posfile.csv', sep='\t', index=False)
SHAREchr3ha_posfile.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/ha/SHAREchr3ha_posfile.csv', sep='\t', index=False)
SHAREchr4ha_posfile.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/ha/SHAREchr4ha_posfile.csv', sep='\t', index=False)
SHAREchr5ha_posfile.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/ha/SHAREchr5ha_posfile.csv', sep='\t', index=False)
SHAREchr6ha_posfile.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/ha/SHAREchr6ha_posfile.csv', sep='\t', index=False)
SHAREchr7ha_posfile.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/ha/SHAREchr7ha_posfile.csv', sep='\t', index=False)
SHAREchr8ha_posfile.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/ha/SHAREchr8ha_posfile.csv', sep='\t', index=False)
SHAREchr9ha_posfile.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/ha/SHAREchr9ha_posfile.csv', sep='\t', index=False)
SHAREchr10ha_posfile.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/ha/SHAREchr10ha_posfile.csv', sep='\t', index=False)
SHAREchr11ha_posfile.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/ha/SHAREchr11ha_posfile.csv', sep='\t', index=False)
SHAREchr12ha_posfile.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/ha/SHAREchr12ha_posfile.csv', sep='\t', index=False)
SHAREchr13ha_posfile.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/ha/SHAREchr13ha_posfile.csv', sep='\t', index=False)
SHAREchr14ha_posfile.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/ha/SHAREchr14ha_posfile.csv', sep='\t', index=False)
SHAREchr15ha_posfile.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/ha/SHAREchr15ha_posfile.csv', sep='\t', index=False)
SHAREchr16ha_posfile.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/ha/SHAREchr16ha_posfile.csv', sep='\t', index=False)
SHAREchr17ha_posfile.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/ha/SHAREchr17ha_posfile.csv', sep='\t', index=False)
SHAREchr18ha_posfile.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/ha/SHAREchr18ha_posfile.csv', sep='\t', index=False)
SHAREchr19ha_posfile.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/ha/SHAREchr19ha_posfile.csv', sep='\t', index=False)
SHAREchr20ha_posfile.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/ha/SHAREchr20ha_posfile.csv', sep='\t', index=False)
SHAREchr21ha_posfile.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/ha/SHAREchr21ha_posfile.csv', sep='\t', index=False)
SHAREchr22ha_posfile.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/ha/SHAREchr22ha_posfile.csv', sep='\t', index=False)

# %%
SHAREchr1aa_posfile.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/aa/SHAREchr1aa_posfile.csv', sep='\t', index=False)
SHAREchr2aa_posfile.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/aa/SHAREchr2aa_posfile.csv', sep='\t', index=False)
SHAREchr3aa_posfile.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/aa/SHAREchr3aa_posfile.csv', sep='\t', index=False)
SHAREchr4aa_posfile.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/aa/SHAREchr4aa_posfile.csv', sep='\t', index=False)
SHAREchr5aa_posfile.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/aa/SHAREchr5aa_posfile.csv', sep='\t', index=False)
SHAREchr6aa_posfile.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/aa/SHAREchr6aa_posfile.csv', sep='\t', index=False)
SHAREchr7aa_posfile.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/aa/SHAREchr7aa_posfile.csv', sep='\t', index=False)
SHAREchr8aa_posfile.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/aa/SHAREchr8aa_posfile.csv', sep='\t', index=False)
SHAREchr9aa_posfile.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/aa/SHAREchr9aa_posfile.csv', sep='\t', index=False)
SHAREchr10aa_posfile.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/aa/SHAREchr10aa_posfile.csv', sep='\t', index=False)
SHAREchr11aa_posfile.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/aa/SHAREchr11aa_posfile.csv', sep='\t', index=False)
SHAREchr12aa_posfile.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/aa/SHAREchr12aa_posfile.csv', sep='\t', index=False)
SHAREchr13aa_posfile.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/aa/SHAREchr13aa_posfile.csv', sep='\t', index=False)
SHAREchr14aa_posfile.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/aa/SHAREchr14aa_posfile.csv', sep='\t', index=False)
SHAREchr15aa_posfile.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/aa/SHAREchr15aa_posfile.csv', sep='\t', index=False)
SHAREchr16aa_posfile.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/aa/SHAREchr16aa_posfile.csv', sep='\t', index=False)
SHAREchr17aa_posfile.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/aa/SHAREchr17aa_posfile.csv', sep='\t', index=False)
SHAREchr18aa_posfile.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/aa/SHAREchr18aa_posfile.csv', sep='\t', index=False)
SHAREchr19aa_posfile.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/aa/SHAREchr19aa_posfile.csv', sep='\t', index=False)
SHAREchr20aa_posfile.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/aa/SHAREchr20aa_posfile.csv', sep='\t', index=False)
SHAREchr21aa_posfile.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/aa/SHAREchr21aa_posfile.csv', sep='\t', index=False)
SHAREchr22aa_posfile.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/aa/SHAREchr22aa_posfile.csv', sep='\t', index=False)

# %% [markdown]
# Next, create the snpannot file for gwastools

# %%
# Load in the info file and the position file:
## African American

SHAREchr1aa_info = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/SHAREchr1aa.info', sep='\t')
SHAREchr1aa_posfile = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/aa/SHAREchr1aa_posfile.csv', sep='\t')

SHAREchr2aa_info = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/SHAREchr2aa.info', sep='\t')
SHAREchr2aa_posfile = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/aa/SHAREchr2aa_posfile.csv', sep='\t')

SHAREchr3aa_info = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/SHAREchr3aa.info', sep='\t')
SHAREchr3aa_posfile = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/aa/SHAREchr3aa_posfile.csv', sep='\t')

SHAREchr4aa_info = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/SHAREchr4aa.info', sep='\t')
SHAREchr4aa_posfile = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/aa/SHAREchr4aa_posfile.csv', sep='\t')

SHAREchr5aa_info = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/SHAREchr5aa.info', sep='\t')
SHAREchr5aa_posfile = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/aa/SHAREchr5aa_posfile.csv', sep='\t')

SHAREchr6aa_info = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/SHAREchr6aa.info', sep='\t')
SHAREchr6aa_posfile = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/aa/SHAREchr6aa_posfile.csv', sep='\t')

SHAREchr7aa_info = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/SHAREchr7aa.info', sep='\t')
SHAREchr7aa_posfile = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/aa/SHAREchr7aa_posfile.csv', sep='\t')

SHAREchr8aa_info = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/SHAREchr8aa.info', sep='\t')
SHAREchr8aa_posfile = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/aa/SHAREchr8aa_posfile.csv', sep='\t')

SHAREchr9aa_info = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/SHAREchr9aa.info', sep='\t')
SHAREchr9aa_posfile = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/aa/SHAREchr9aa_posfile.csv', sep='\t')

SHAREchr10aa_info = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/SHAREchr10aa.info', sep='\t')
SHAREchr10aa_posfile = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/aa/SHAREchr10aa_posfile.csv', sep='\t')

SHAREchr11aa_info = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/SHAREchr11aa.info', sep='\t')
SHAREchr11aa_posfile = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/aa/SHAREchr11aa_posfile.csv', sep='\t')

SHAREchr12aa_info = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/SHAREchr12aa.info', sep='\t')
SHAREchr12aa_posfile = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/aa/SHAREchr12aa_posfile.csv', sep='\t')

SHAREchr13aa_info = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/SHAREchr13aa.info', sep='\t')
SHAREchr13aa_posfile = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/aa/SHAREchr13aa_posfile.csv', sep='\t')

SHAREchr14aa_info = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/SHAREchr14aa.info', sep='\t')
SHAREchr14aa_posfile = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/aa/SHAREchr14aa_posfile.csv', sep='\t')

SHAREchr15aa_info = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/SHAREchr15aa.info', sep='\t')
SHAREchr15aa_posfile = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/aa/SHAREchr15aa_posfile.csv', sep='\t')

SHAREchr16aa_info = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/SHAREchr16aa.info', sep='\t')
SHAREchr16aa_posfile = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/aa/SHAREchr16aa_posfile.csv', sep='\t')

SHAREchr17aa_info = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/SHAREchr17aa.info', sep='\t')
SHAREchr17aa_posfile = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/aa/SHAREchr17aa_posfile.csv', sep='\t')

SHAREchr18aa_info = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/SHAREchr18aa.info', sep='\t')
SHAREchr18aa_posfile = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/aa/SHAREchr18aa_posfile.csv', sep='\t')

SHAREchr19aa_info = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/SHAREchr19aa.info', sep='\t')
SHAREchr19aa_posfile = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/aa/SHAREchr19aa_posfile.csv', sep='\t')

SHAREchr20aa_info = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/SHAREchr20aa.info', sep='\t')
SHAREchr20aa_posfile = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/aa/SHAREchr20aa_posfile.csv', sep='\t')

SHAREchr21aa_info = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_aa.genotype-imputed-data.c1/SHAREchr21aa.info', sep='\t')
SHAREchr21aa_posfile = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/aa/SHAREchr21aa_posfile.csv', sep='\t')


## Hispanic American

SHAREchr1ha_info = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/SHAREchr1ha.info', sep='\t')
SHAREchr1ha_posfile = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/ha/SHAREchr1ha_posfile.csv', sep='\t')

SHAREchr2ha_info = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/SHAREchr2ha.info', sep='\t')
SHAREchr2ha_posfile = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/ha/SHAREchr2ha_posfile.csv', sep='\t')

SHAREchr3ha_info = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/SHAREchr3ha.info', sep='\t')
SHAREchr3ha_posfile = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/ha/SHAREchr3ha_posfile.csv', sep='\t')

SHAREchr4ha_info = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/SHAREchr4ha.info', sep='\t')
SHAREchr4ha_posfile = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/ha/SHAREchr4ha_posfile.csv', sep='\t')

SHAREchr5ha_info = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/SHAREchr5ha.info', sep='\t')
SHAREchr5ha_posfile = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/ha/SHAREchr5ha_posfile.csv', sep='\t')

SHAREchr6ha_info = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/SHAREchr6ha.info', sep='\t')
SHAREchr6ha_posfile = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/ha/SHAREchr6ha_posfile.csv', sep='\t')

SHAREchr7ha_info = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/SHAREchr7ha.info', sep='\t')
SHAREchr7ha_posfile = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/ha/SHAREchr7ha_posfile.csv', sep='\t')

SHAREchr8ha_info = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/SHAREchr8ha.info', sep='\t')
SHAREchr8ha_posfile = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/ha/SHAREchr8ha_posfile.csv', sep='\t')

SHAREchr9ha_info = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/SHAREchr9ha.info', sep='\t')
SHAREchr9ha_posfile = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/ha/SHAREchr9ha_posfile.csv', sep='\t')

SHAREchr10ha_info = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/SHAREchr10ha.info', sep='\t')
SHAREchr10ha_posfile = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/ha/SHAREchr10ha_posfile.csv', sep='\t')

SHAREchr11ha_info = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/SHAREchr11ha.info', sep='\t')
SHAREchr11ha_posfile = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/ha/SHAREchr11ha_posfile.csv', sep='\t')

SHAREchr12ha_info = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/SHAREchr12ha.info', sep='\t')
SHAREchr12ha_posfile = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/ha/SHAREchr12ha_posfile.csv', sep='\t')

SHAREchr13ha_info = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/SHAREchr13ha.info', sep='\t')
SHAREchr13ha_posfile = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/ha/SHAREchr13ha_posfile.csv', sep='\t')

SHAREchr14ha_info = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/SHAREchr14ha.info', sep='\t')
SHAREchr14ha_posfile = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/ha/SHAREchr14ha_posfile.csv', sep='\t')

SHAREchr15ha_info = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/SHAREchr15ha.info', sep='\t')
SHAREchr15ha_posfile = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/ha/SHAREchr15ha_posfile.csv', sep='\t')

SHAREchr16ha_info = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/SHAREchr16ha.info', sep='\t')
SHAREchr16ha_posfile = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/ha/SHAREchr16ha_posfile.csv', sep='\t')

SHAREchr17ha_info = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/SHAREchr17ha.info', sep='\t')
SHAREchr17ha_posfile = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/ha/SHAREchr17ha_posfile.csv', sep='\t')

SHAREchr18ha_info = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/SHAREchr18ha.info', sep='\t')
SHAREchr18ha_posfile = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/ha/SHAREchr18ha_posfile.csv', sep='\t')

SHAREchr19ha_info = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/SHAREchr19ha.info', sep='\t')
SHAREchr19ha_posfile = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/ha/SHAREchr19ha_posfile.csv', sep='\t')

SHAREchr20ha_info = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/SHAREchr20ha.info', sep='\t')
SHAREchr20ha_posfile = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/ha/SHAREchr20ha_posfile.csv', sep='\t')

SHAREchr21ha_info = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/phg000592.v1.WHI_SHARE_ha.genotype-imputed-data.c1/SHAREchr21ha.info', sep='\t')
SHAREchr21ha_posfile = pd.read_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/posfiles/ha/SHAREchr21ha_posfile.csv', sep='\t')



# Modify posfile
## African American

SHAREchr1aa_posfile['chromosome'] = 1
SHAREchr1aa_posfile.reset_index(level=0, inplace=True)
SHAREchr1aa_posfile = SHAREchr1aa_posfile.rename(columns={"index": "snpid"})

SHAREchr2aa_posfile['chromosome'] = 1
SHAREchr2aa_posfile.reset_index(level=0, inplace=True)
SHAREchr2aa_posfile = SHAREchr2aa_posfile.rename(columns={"index": "snpid"})

SHAREchr3aa_posfile['chromosome'] = 1
SHAREchr3aa_posfile.reset_index(level=0, inplace=True)
SHAREchr3aa_posfile = SHAREchr3aa_posfile.rename(columns={"index": "snpid"})

SHAREchr4aa_posfile['chromosome'] = 1
SHAREchr4aa_posfile.reset_index(level=0, inplace=True)
SHAREchr4aa_posfile = SHAREchr4aa_posfile.rename(columns={"index": "snpid"})

SHAREchr5aa_posfile['chromosome'] = 1
SHAREchr5aa_posfile.reset_index(level=0, inplace=True)
SHAREchr5aa_posfile = SHAREchr5aa_posfile.rename(columns={"index": "snpid"})

SHAREchr6aa_posfile['chromosome'] = 1
SHAREchr6aa_posfile.reset_index(level=0, inplace=True)
SHAREchr6aa_posfile = SHAREchr6aa_posfile.rename(columns={"index": "snpid"})

SHAREchr7aa_posfile['chromosome'] = 1
SHAREchr7aa_posfile.reset_index(level=0, inplace=True)
SHAREchr7aa_posfile = SHAREchr7aa_posfile.rename(columns={"index": "snpid"})

SHAREchr8aa_posfile['chromosome'] = 1
SHAREchr8aa_posfile.reset_index(level=0, inplace=True)
SHAREchr8aa_posfile = SHAREchr8aa_posfile.rename(columns={"index": "snpid"})

SHAREchr9aa_posfile['chromosome'] = 1
SHAREchr9aa_posfile.reset_index(level=0, inplace=True)
SHAREchr9aa_posfile = SHAREchr9aa_posfile.rename(columns={"index": "snpid"})

SHAREchr10aa_posfile['chromosome'] = 1
SHAREchr10aa_posfile.reset_index(level=0, inplace=True)
SHAREchr10aa_posfile = SHAREchr10aa_posfile.rename(columns={"index": "snpid"})

SHAREchr11aa_posfile['chromosome'] = 1
SHAREchr11aa_posfile.reset_index(level=0, inplace=True)
SHAREchr11aa_posfile = SHAREchr11aa_posfile.rename(columns={"index": "snpid"})

SHAREchr12aa_posfile['chromosome'] = 1
SHAREchr12aa_posfile.reset_index(level=0, inplace=True)
SHAREchr12aa_posfile = SHAREchr12aa_posfile.rename(columns={"index": "snpid"})

SHAREchr13aa_posfile['chromosome'] = 1
SHAREchr13aa_posfile.reset_index(level=0, inplace=True)
SHAREchr13aa_posfile = SHAREchr13aa_posfile.rename(columns={"index": "snpid"})

SHAREchr14aa_posfile['chromosome'] = 1
SHAREchr14aa_posfile.reset_index(level=0, inplace=True)
SHAREchr14aa_posfile = SHAREchr14aa_posfile.rename(columns={"index": "snpid"})

SHAREchr15aa_posfile['chromosome'] = 1
SHAREchr15aa_posfile.reset_index(level=0, inplace=True)
SHAREchr15aa_posfile = SHAREchr15aa_posfile.rename(columns={"index": "snpid"})

SHAREchr16aa_posfile['chromosome'] = 1
SHAREchr16aa_posfile.reset_index(level=0, inplace=True)
SHAREchr16aa_posfile = SHAREchr16aa_posfile.rename(columns={"index": "snpid"})

SHAREchr17aa_posfile['chromosome'] = 1
SHAREchr17aa_posfile.reset_index(level=0, inplace=True)
SHAREchr17aa_posfile = SHAREchr17aa_posfile.rename(columns={"index": "snpid"})

SHAREchr18aa_posfile['chromosome'] = 1
SHAREchr18aa_posfile.reset_index(level=0, inplace=True)
SHAREchr18aa_posfile = SHAREchr18aa_posfile.rename(columns={"index": "snpid"})

SHAREchr19aa_posfile['chromosome'] = 1
SHAREchr19aa_posfile.reset_index(level=0, inplace=True)
SHAREchr19aa_posfile = SHAREchr19aa_posfile.rename(columns={"index": "snpid"})

SHAREchr20aa_posfile['chromosome'] = 1
SHAREchr20aa_posfile.reset_index(level=0, inplace=True)
SHAREchr20aa_posfile = SHAREchr20aa_posfile.rename(columns={"index": "snpid"})

SHAREchr21aa_posfile['chromosome'] = 21
SHAREchr21aa_posfile.reset_index(level=0, inplace=True)
SHAREchr21aa_posfile = SHAREchr21aa_posfile.rename(columns={"index": "snpid"})


## Hispanic American

SHAREchr1ha_posfile['chromosome'] = 1
SHAREchr1ha_posfile.reset_index(level=0, inplace=True)
SHAREchr1ha_posfile = SHAREchr1ha_posfile.rename(columns={"index": "snpid"})

SHAREchr2ha_posfile['chromosome'] = 1
SHAREchr2ha_posfile.reset_index(level=0, inplace=True)
SHAREchr2ha_posfile = SHAREchr2ha_posfile.rename(columns={"index": "snpid"})

SHAREchr3ha_posfile['chromosome'] = 1
SHAREchr3ha_posfile.reset_index(level=0, inplace=True)
SHAREchr3ha_posfile = SHAREchr3ha_posfile.rename(columns={"index": "snpid"})

SHAREchr4ha_posfile['chromosome'] = 1
SHAREchr4ha_posfile.reset_index(level=0, inplace=True)
SHAREchr4ha_posfile = SHAREchr4ha_posfile.rename(columns={"index": "snpid"})

SHAREchr5ha_posfile['chromosome'] = 1
SHAREchr5ha_posfile.reset_index(level=0, inplace=True)
SHAREchr5ha_posfile = SHAREchr5ha_posfile.rename(columns={"index": "snpid"})

SHAREchr6ha_posfile['chromosome'] = 1
SHAREchr6ha_posfile.reset_index(level=0, inplace=True)
SHAREchr6ha_posfile = SHAREchr6ha_posfile.rename(columns={"index": "snpid"})

SHAREchr7ha_posfile['chromosome'] = 1
SHAREchr7ha_posfile.reset_index(level=0, inplace=True)
SHAREchr7ha_posfile = SHAREchr7ha_posfile.rename(columns={"index": "snpid"})

SHAREchr8ha_posfile['chromosome'] = 1
SHAREchr8ha_posfile.reset_index(level=0, inplace=True)
SHAREchr8ha_posfile = SHAREchr8ha_posfile.rename(columns={"index": "snpid"})

SHAREchr9ha_posfile['chromosome'] = 1
SHAREchr9ha_posfile.reset_index(level=0, inplace=True)
SHAREchr9ha_posfile = SHAREchr9ha_posfile.rename(columns={"index": "snpid"})

SHAREchr10ha_posfile['chromosome'] = 1
SHAREchr10ha_posfile.reset_index(level=0, inplace=True)
SHAREchr10ha_posfile = SHAREchr10ha_posfile.rename(columns={"index": "snpid"})

SHAREchr11ha_posfile['chromosome'] = 1
SHAREchr11ha_posfile.reset_index(level=0, inplace=True)
SHAREchr11ha_posfile = SHAREchr11ha_posfile.rename(columns={"index": "snpid"})

SHAREchr12ha_posfile['chromosome'] = 1
SHAREchr12ha_posfile.reset_index(level=0, inplace=True)
SHAREchr12ha_posfile = SHAREchr12ha_posfile.rename(columns={"index": "snpid"})

SHAREchr13ha_posfile['chromosome'] = 1
SHAREchr13ha_posfile.reset_index(level=0, inplace=True)
SHAREchr13ha_posfile = SHAREchr13ha_posfile.rename(columns={"index": "snpid"})

SHAREchr14ha_posfile['chromosome'] = 1
SHAREchr14ha_posfile.reset_index(level=0, inplace=True)
SHAREchr14ha_posfile = SHAREchr14ha_posfile.rename(columns={"index": "snpid"})

SHAREchr15ha_posfile['chromosome'] = 1
SHAREchr15ha_posfile.reset_index(level=0, inplace=True)
SHAREchr15ha_posfile = SHAREchr15ha_posfile.rename(columns={"index": "snpid"})

SHAREchr16ha_posfile['chromosome'] = 1
SHAREchr16ha_posfile.reset_index(level=0, inplace=True)
SHAREchr16ha_posfile = SHAREchr16ha_posfile.rename(columns={"index": "snpid"})

SHAREchr17ha_posfile['chromosome'] = 1
SHAREchr17ha_posfile.reset_index(level=0, inplace=True)
SHAREchr17ha_posfile = SHAREchr17ha_posfile.rename(columns={"index": "snpid"})

SHAREchr18ha_posfile['chromosome'] = 1
SHAREchr18ha_posfile.reset_index(level=0, inplace=True)
SHAREchr18ha_posfile = SHAREchr18ha_posfile.rename(columns={"index": "snpid"})

SHAREchr19ha_posfile['chromosome'] = 1
SHAREchr19ha_posfile.reset_index(level=0, inplace=True)
SHAREchr19ha_posfile = SHAREchr19ha_posfile.rename(columns={"index": "snpid"})

SHAREchr20ha_posfile['chromosome'] = 1
SHAREchr20ha_posfile.reset_index(level=0, inplace=True)
SHAREchr20ha_posfile = SHAREchr20ha_posfile.rename(columns={"index": "snpid"})

SHAREchr21ha_posfile['chromosome'] = 21
SHAREchr21ha_posfile.reset_index(level=0, inplace=True)
SHAREchr21ha_posfile = SHAREchr21ha_posfile.rename(columns={"index": "snpid"})



# Concatonate the two files, and rename columns as they lose their name
## African American

chr1aa_snpannot = pd.concat([SHAREchr1aa_posfile, SHAREchr1aa_info[['Al1', 'Al2']], ], ignore_index=True, sort=False, axis=1)
chr1aa_snpannot = chr1aa_snpannot.rename(columns={0: "snpid", 1: "SNP ", 2: "position", 3: 'chromosome', 4:'alleleA', 5: 'alleleB'})

chr2aa_snpannot = pd.concat([SHAREchr2aa_posfile, SHAREchr2aa_info[['Al1', 'Al2']], ], ignore_index=True, sort=False, axis=1)
chr2aa_snpannot = chr2aa_snpannot.rename(columns={0: "snpid", 1: "SNP ", 2: "position", 3: 'chromosome', 4:'alleleA', 5: 'alleleB'})

chr3aa_snpannot = pd.concat([SHAREchr3aa_posfile, SHAREchr3aa_info[['Al1', 'Al2']], ], ignore_index=True, sort=False, axis=1)
chr3aa_snpannot = chr3aa_snpannot.rename(columns={0: "snpid", 1: "SNP ", 2: "position", 3: 'chromosome', 4:'alleleA', 5: 'alleleB'})

chr4aa_snpannot = pd.concat([SHAREchr4aa_posfile, SHAREchr4aa_info[['Al1', 'Al2']], ], ignore_index=True, sort=False, axis=1)
chr4aa_snpannot = chr4aa_snpannot.rename(columns={0: "snpid", 1: "SNP ", 2: "position", 3: 'chromosome', 4:'alleleA', 5: 'alleleB'})

chr5aa_snpannot = pd.concat([SHAREchr5aa_posfile, SHAREchr5aa_info[['Al1', 'Al2']], ], ignore_index=True, sort=False, axis=1)
chr5aa_snpannot = chr5aa_snpannot.rename(columns={0: "snpid", 1: "SNP ", 2: "position", 3: 'chromosome', 4:'alleleA', 5: 'alleleB'})

chr6aa_snpannot = pd.concat([SHAREchr6aa_posfile, SHAREchr6aa_info[['Al1', 'Al2']], ], ignore_index=True, sort=False, axis=1)
chr6aa_snpannot = chr6aa_snpannot.rename(columns={0: "snpid", 1: "SNP ", 2: "position", 3: 'chromosome', 4:'alleleA', 5: 'alleleB'})

chr7aa_snpannot = pd.concat([SHAREchr7aa_posfile, SHAREchr7aa_info[['Al1', 'Al2']], ], ignore_index=True, sort=False, axis=1)
chr7aa_snpannot = chr7aa_snpannot.rename(columns={0: "snpid", 1: "SNP ", 2: "position", 3: 'chromosome', 4:'alleleA', 5: 'alleleB'})

chr8aa_snpannot = pd.concat([SHAREchr8aa_posfile, SHAREchr8aa_info[['Al1', 'Al2']], ], ignore_index=True, sort=False, axis=1)
chr8aa_snpannot = chr8aa_snpannot.rename(columns={0: "snpid", 1: "SNP ", 2: "position", 3: 'chromosome', 4:'alleleA', 5: 'alleleB'})

chr9aa_snpannot = pd.concat([SHAREchr9aa_posfile, SHAREchr9aa_info[['Al1', 'Al2']], ], ignore_index=True, sort=False, axis=1)
chr9aa_snpannot = chr9aa_snpannot.rename(columns={0: "snpid", 1: "SNP ", 2: "position", 3: 'chromosome', 4:'alleleA', 5: 'alleleB'})

chr10aa_snpannot = pd.concat([SHAREchr10aa_posfile, SHAREchr10aa_info[['Al1', 'Al2']], ], ignore_index=True, sort=False, axis=1)
chr10aa_snpannot = chr10aa_snpannot.rename(columns={0: "snpid", 1: "SNP ", 2: "position", 3: 'chromosome', 4:'alleleA', 5: 'alleleB'})

chr11aa_snpannot = pd.concat([SHAREchr11aa_posfile, SHAREchr11aa_info[['Al1', 'Al2']], ], ignore_index=True, sort=False, axis=1)
chr11aa_snpannot = chr11aa_snpannot.rename(columns={0: "snpid", 1: "SNP ", 2: "position", 3: 'chromosome', 4:'alleleA', 5: 'alleleB'})

chr12aa_snpannot = pd.concat([SHAREchr12aa_posfile, SHAREchr12aa_info[['Al1', 'Al2']], ], ignore_index=True, sort=False, axis=1)
chr12aa_snpannot = chr12aa_snpannot.rename(columns={0: "snpid", 1: "SNP ", 2: "position", 3: 'chromosome', 4:'alleleA', 5: 'alleleB'})

chr13aa_snpannot = pd.concat([SHAREchr13aa_posfile, SHAREchr13aa_info[['Al1', 'Al2']], ], ignore_index=True, sort=False, axis=1)
chr13aa_snpannot = chr13aa_snpannot.rename(columns={0: "snpid", 1: "SNP ", 2: "position", 3: 'chromosome', 4:'alleleA', 5: 'alleleB'})

chr14aa_snpannot = pd.concat([SHAREchr14aa_posfile, SHAREchr14aa_info[['Al1', 'Al2']], ], ignore_index=True, sort=False, axis=1)
chr14aa_snpannot = chr14aa_snpannot.rename(columns={0: "snpid", 1: "SNP ", 2: "position", 3: 'chromosome', 4:'alleleA', 5: 'alleleB'})

chr15aa_snpannot = pd.concat([SHAREchr15aa_posfile, SHAREchr15aa_info[['Al1', 'Al2']], ], ignore_index=True, sort=False, axis=1)
chr15aa_snpannot = chr15aa_snpannot.rename(columns={0: "snpid", 1: "SNP ", 2: "position", 3: 'chromosome', 4:'alleleA', 5: 'alleleB'})

chr16aa_snpannot = pd.concat([SHAREchr16aa_posfile, SHAREchr16aa_info[['Al1', 'Al2']], ], ignore_index=True, sort=False, axis=1)
chr16aa_snpannot = chr16aa_snpannot.rename(columns={0: "snpid", 1: "SNP ", 2: "position", 3: 'chromosome', 4:'alleleA', 5: 'alleleB'})

chr17aa_snpannot = pd.concat([SHAREchr17aa_posfile, SHAREchr17aa_info[['Al1', 'Al2']], ], ignore_index=True, sort=False, axis=1)
chr17aa_snpannot = chr17aa_snpannot.rename(columns={0: "snpid", 1: "SNP ", 2: "position", 3: 'chromosome', 4:'alleleA', 5: 'alleleB'})

chr18aa_snpannot = pd.concat([SHAREchr18aa_posfile, SHAREchr18aa_info[['Al1', 'Al2']], ], ignore_index=True, sort=False, axis=1)
chr18aa_snpannot = chr18aa_snpannot.rename(columns={0: "snpid", 1: "SNP ", 2: "position", 3: 'chromosome', 4:'alleleA', 5: 'alleleB'})

chr19aa_snpannot = pd.concat([SHAREchr19aa_posfile, SHAREchr19aa_info[['Al1', 'Al2']], ], ignore_index=True, sort=False, axis=1)
chr19aa_snpannot = chr19aa_snpannot.rename(columns={0: "snpid", 1: "SNP ", 2: "position", 3: 'chromosome', 4:'alleleA', 5: 'alleleB'})

chr20aa_snpannot = pd.concat([SHAREchr20aa_posfile, SHAREchr20aa_info[['Al1', 'Al2']], ], ignore_index=True, sort=False, axis=1)
chr20aa_snpannot = chr20aa_snpannot.rename(columns={0: "snpid", 1: "SNP ", 2: "position", 3: 'chromosome', 4:'alleleA', 5: 'alleleB'})

chr21aa_snpannot = pd.concat([SHAREchr21aa_posfile, SHAREchr21aa_info[['Al1', 'Al2']], ], ignore_index=True, sort=False, axis=1)
chr21aa_snpannot = chr21aa_snpannot.rename(columns={0: "snpid", 1: "SNP ", 2: "position", 3: 'chromosome', 4:'alleleA', 5: 'alleleB'})

## Hispanic American

chr1ha_snpannot = pd.concat([SHAREchr1ha_posfile, SHAREchr1ha_info[['Al1', 'Al2']], ], ignore_index=True, sort=False, axis=1)
chr1ha_snpannot = chr1ha_snpannot.rename(columns={0: "snpid", 1: "SNP ", 2: "position", 3: 'chromosome', 4:'alleleA', 5: 'alleleB'})

chr2ha_snpannot = pd.concat([SHAREchr2ha_posfile, SHAREchr2ha_info[['Al1', 'Al2']], ], ignore_index=True, sort=False, axis=1)
chr2ha_snpannot = chr2ha_snpannot.rename(columns={0: "snpid", 1: "SNP ", 2: "position", 3: 'chromosome', 4:'alleleA', 5: 'alleleB'})

chr3ha_snpannot = pd.concat([SHAREchr3ha_posfile, SHAREchr3ha_info[['Al1', 'Al2']], ], ignore_index=True, sort=False, axis=1)
chr3ha_snpannot = chr3ha_snpannot.rename(columns={0: "snpid", 1: "SNP ", 2: "position", 3: 'chromosome', 4:'alleleA', 5: 'alleleB'})

chr4ha_snpannot = pd.concat([SHAREchr4ha_posfile, SHAREchr4ha_info[['Al1', 'Al2']], ], ignore_index=True, sort=False, axis=1)
chr4ha_snpannot = chr4ha_snpannot.rename(columns={0: "snpid", 1: "SNP ", 2: "position", 3: 'chromosome', 4:'alleleA', 5: 'alleleB'})

chr5ha_snpannot = pd.concat([SHAREchr5ha_posfile, SHAREchr5ha_info[['Al1', 'Al2']], ], ignore_index=True, sort=False, axis=1)
chr5ha_snpannot = chr5ha_snpannot.rename(columns={0: "snpid", 1: "SNP ", 2: "position", 3: 'chromosome', 4:'alleleA', 5: 'alleleB'})

chr6ha_snpannot = pd.concat([SHAREchr6ha_posfile, SHAREchr6ha_info[['Al1', 'Al2']], ], ignore_index=True, sort=False, axis=1)
chr6ha_snpannot = chr6ha_snpannot.rename(columns={0: "snpid", 1: "SNP ", 2: "position", 3: 'chromosome', 4:'alleleA', 5: 'alleleB'})

chr7ha_snpannot = pd.concat([SHAREchr7ha_posfile, SHAREchr7ha_info[['Al1', 'Al2']], ], ignore_index=True, sort=False, axis=1)
chr7ha_snpannot = chr7ha_snpannot.rename(columns={0: "snpid", 1: "SNP ", 2: "position", 3: 'chromosome', 4:'alleleA', 5: 'alleleB'})

chr8ha_snpannot = pd.concat([SHAREchr8ha_posfile, SHAREchr8ha_info[['Al1', 'Al2']], ], ignore_index=True, sort=False, axis=1)
chr8ha_snpannot = chr8ha_snpannot.rename(columns={0: "snpid", 1: "SNP ", 2: "position", 3: 'chromosome', 4:'alleleA', 5: 'alleleB'})

chr9ha_snpannot = pd.concat([SHAREchr9ha_posfile, SHAREchr9ha_info[['Al1', 'Al2']], ], ignore_index=True, sort=False, axis=1)
chr9ha_snpannot = chr9ha_snpannot.rename(columns={0: "snpid", 1: "SNP ", 2: "position", 3: 'chromosome', 4:'alleleA', 5: 'alleleB'})

chr10ha_snpannot = pd.concat([SHAREchr10ha_posfile, SHAREchr10ha_info[['Al1', 'Al2']], ], ignore_index=True, sort=False, axis=1)
chr10ha_snpannot = chr10ha_snpannot.rename(columns={0: "snpid", 1: "SNP ", 2: "position", 3: 'chromosome', 4:'alleleA', 5: 'alleleB'})

chr11ha_snpannot = pd.concat([SHAREchr11ha_posfile, SHAREchr11ha_info[['Al1', 'Al2']], ], ignore_index=True, sort=False, axis=1)
chr11ha_snpannot = chr11ha_snpannot.rename(columns={0: "snpid", 1: "SNP ", 2: "position", 3: 'chromosome', 4:'alleleA', 5: 'alleleB'})

chr12ha_snpannot = pd.concat([SHAREchr12ha_posfile, SHAREchr12ha_info[['Al1', 'Al2']], ], ignore_index=True, sort=False, axis=1)
chr12ha_snpannot = chr12ha_snpannot.rename(columns={0: "snpid", 1: "SNP ", 2: "position", 3: 'chromosome', 4:'alleleA', 5: 'alleleB'})

chr13ha_snpannot = pd.concat([SHAREchr13ha_posfile, SHAREchr13ha_info[['Al1', 'Al2']], ], ignore_index=True, sort=False, axis=1)
chr13ha_snpannot = chr13ha_snpannot.rename(columns={0: "snpid", 1: "SNP ", 2: "position", 3: 'chromosome', 4:'alleleA', 5: 'alleleB'})

chr14ha_snpannot = pd.concat([SHAREchr14ha_posfile, SHAREchr14ha_info[['Al1', 'Al2']], ], ignore_index=True, sort=False, axis=1)
chr14ha_snpannot = chr14ha_snpannot.rename(columns={0: "snpid", 1: "SNP ", 2: "position", 3: 'chromosome', 4:'alleleA', 5: 'alleleB'})

chr15ha_snpannot = pd.concat([SHAREchr15ha_posfile, SHAREchr15ha_info[['Al1', 'Al2']], ], ignore_index=True, sort=False, axis=1)
chr15ha_snpannot = chr15ha_snpannot.rename(columns={0: "snpid", 1: "SNP ", 2: "position", 3: 'chromosome', 4:'alleleA', 5: 'alleleB'})

chr16ha_snpannot = pd.concat([SHAREchr16ha_posfile, SHAREchr16ha_info[['Al1', 'Al2']], ], ignore_index=True, sort=False, axis=1)
chr16ha_snpannot = chr16ha_snpannot.rename(columns={0: "snpid", 1: "SNP ", 2: "position", 3: 'chromosome', 4:'alleleA', 5: 'alleleB'})

chr17ha_snpannot = pd.concat([SHAREchr17ha_posfile, SHAREchr17ha_info[['Al1', 'Al2']], ], ignore_index=True, sort=False, axis=1)
chr17ha_snpannot = chr17ha_snpannot.rename(columns={0: "snpid", 1: "SNP ", 2: "position", 3: 'chromosome', 4:'alleleA', 5: 'alleleB'})

chr18ha_snpannot = pd.concat([SHAREchr18ha_posfile, SHAREchr18ha_info[['Al1', 'Al2']], ], ignore_index=True, sort=False, axis=1)
chr18ha_snpannot = chr18ha_snpannot.rename(columns={0: "snpid", 1: "SNP ", 2: "position", 3: 'chromosome', 4:'alleleA', 5: 'alleleB'})

chr19ha_snpannot = pd.concat([SHAREchr19ha_posfile, SHAREchr19ha_info[['Al1', 'Al2']], ], ignore_index=True, sort=False, axis=1)
chr19ha_snpannot = chr19ha_snpannot.rename(columns={0: "snpid", 1: "SNP ", 2: "position", 3: 'chromosome', 4:'alleleA', 5: 'alleleB'})

chr20ha_snpannot = pd.concat([SHAREchr20ha_posfile, SHAREchr20ha_info[['Al1', 'Al2']], ], ignore_index=True, sort=False, axis=1)
chr20ha_snpannot = chr20ha_snpannot.rename(columns={0: "snpid", 1: "SNP ", 2: "position", 3: 'chromosome', 4:'alleleA', 5: 'alleleB'})

chr21ha_snpannot = pd.concat([SHAREchr21ha_posfile, SHAREchr21ha_info[['Al1', 'Al2']], ], ignore_index=True, sort=False, axis=1)
chr21ha_snpannot = chr21ha_snpannot.rename(columns={0: "snpid", 1: "SNP ", 2: "position", 3: 'chromosome', 4:'alleleA', 5: 'alleleB'})


# Save snpfile
## African American

chr1aa_snpannot.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/snpannotfiles/chr1aa_snpannot', sep='\t', index=False)
chr2aa_snpannot.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/snpannotfiles/chr2aa_snpannot', sep='\t', index=False)
chr3aa_snpannot.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/snpannotfiles/chr3aa_snpannot', sep='\t', index=False)
chr4aa_snpannot.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/snpannotfiles/chr4aa_snpannot', sep='\t', index=False)
chr5aa_snpannot.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/snpannotfiles/chr5aa_snpannot', sep='\t', index=False)
chr6aa_snpannot.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/snpannotfiles/chr6aa_snpannot', sep='\t', index=False)
chr7aa_snpannot.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/snpannotfiles/chr7aa_snpannot', sep='\t', index=False)
chr8aa_snpannot.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/snpannotfiles/chr8aa_snpannot', sep='\t', index=False)
chr9aa_snpannot.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/snpannotfiles/chr9aa_snpannot', sep='\t', index=False)
chr10aa_snpannot.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/snpannotfiles/chr10aa_snpannot', sep='\t', index=False)
chr11aa_snpannot.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/snpannotfiles/chr11aa_snpannot', sep='\t', index=False)
chr12aa_snpannot.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/snpannotfiles/chr12aa_snpannot', sep='\t', index=False)
chr13aa_snpannot.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/snpannotfiles/chr13aa_snpannot', sep='\t', index=False)
chr14aa_snpannot.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/snpannotfiles/chr14aa_snpannot', sep='\t', index=False)
chr15aa_snpannot.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/snpannotfiles/chr15aa_snpannot', sep='\t', index=False)
chr16aa_snpannot.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/snpannotfiles/chr16aa_snpannot', sep='\t', index=False)
chr17aa_snpannot.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/snpannotfiles/chr17aa_snpannot', sep='\t', index=False)
chr18aa_snpannot.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/snpannotfiles/chr18aa_snpannot', sep='\t', index=False)
chr19aa_snpannot.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/snpannotfiles/chr19aa_snpannot', sep='\t', index=False)
chr20aa_snpannot.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/snpannotfiles/chr20aa_snpannot', sep='\t', index=False)
chr21aa_snpannot.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/snpannotfiles/chr21aa_snpannot', sep='\t', index=False)

##Hispanic American


chr1ha_snpannot.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/snpannotfiles/chr1ha_snpannot', sep='\t', index=False)
chr2ha_snpannot.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/snpannotfiles/chr2ha_snpannot', sep='\t', index=False)
chr3ha_snpannot.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/snpannotfiles/chr3ha_snpannot', sep='\t', index=False)
chr4ha_snpannot.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/snpannotfiles/chr4ha_snpannot', sep='\t', index=False)
chr5ha_snpannot.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/snpannotfiles/chr5ha_snpannot', sep='\t', index=False)
chr6ha_snpannot.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/snpannotfiles/chr6ha_snpannot', sep='\t', index=False)
chr7ha_snpannot.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/snpannotfiles/chr7ha_snpannot', sep='\t', index=False)
chr8ha_snpannot.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/snpannotfiles/chr8ha_snpannot', sep='\t', index=False)
chr9ha_snpannot.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/snpannotfiles/chr9ha_snpannot', sep='\t', index=False)
chr10ha_snpannot.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/snpannotfiles/chr10ha_snpannot', sep='\t', index=False)
chr11ha_snpannot.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/snpannotfiles/chr11ha_snpannot', sep='\t', index=False)
chr12ha_snpannot.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/snpannotfiles/chr12ha_snpannot', sep='\t', index=False)
chr13ha_snpannot.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/snpannotfiles/chr13ha_snpannot', sep='\t', index=False)
chr14ha_snpannot.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/snpannotfiles/chr14ha_snpannot', sep='\t', index=False)
chr15ha_snpannot.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/snpannotfiles/chr15ha_snpannot', sep='\t', index=False)
chr16ha_snpannot.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/snpannotfiles/chr16ha_snpannot', sep='\t', index=False)
chr17ha_snpannot.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/snpannotfiles/chr17ha_snpannot', sep='\t', index=False)
chr18ha_snpannot.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/snpannotfiles/chr18ha_snpannot', sep='\t', index=False)
chr19ha_snpannot.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/snpannotfiles/chr19ha_snpannot', sep='\t', index=False)
chr20ha_snpannot.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/snpannotfiles/chr20ha_snpannot', sep='\t', index=False)
chr21ha_snpannot.to_csv('/home/anbennett2/dbgap_data/WHI/consentgroup_1/phenogeno/geno/746/snpannotfiles/chr21ha_snpannot', sep='\t', index=False)
